# %%
import requests
from bs4 import BeautifulSoup as bs
import urllib

# %%
url = "https://medlineplus.gov/lab-tests/"

# %%
res = requests.get(url)
html = bs(res.content,'html.parser')
html

# %%
id = ['section_'+chr(x+65) for x in range(26)]

# %%
links = html.find_all('div',id=id[0])
links = [i.find_all('li') for i in links][0]
# print(links[0][0].find('a').get('href'))
links = [t.find('a').get('href') for t in links]
# links[0].find('a').get('href')

# %%
links =[]
for i in id:
    try:
        # print(i)
        temp = html.find_all('div',id=i)
        temp = [j.find_all('li') for j in temp][0]
        temp = [t.find('a').get('href') for t in temp]
       
    except:
        print(i)
    
    links = links+temp

links
# Out:
# section_J
# section_Q
# ['https://medlineplus.gov/lab-tests/acetaminophen-level/',
#  'https://medlineplus.gov/lab-tests/acid-fast-bacillus-afb-tests/',
#  'https://medlineplus.gov/lab-tests/adhd-screening/',
#  'https://medlineplus.gov/lab-tests/adrenocorticotropic-hormone-acth/',
#  'https://medlineplus.gov/lab-tests/albumin-blood-test/',
#  'https://medlineplus.gov/lab-tests/alcohol-use-screening-tests/',
#  'https://medlineplus.gov/lab-tests/aldosterone-test/',
#  'https://medlineplus.gov/lab-tests/alkaline-phosphatase/',
#  'https://medlineplus.gov/lab-tests/allergy-blood-test/',
#  'https://medlineplus.gov/lab-tests/allergy-skin-test/',
#  'https://medlineplus.gov/lab-tests/alpha-fetoprotein-afp-tumor-marker-test/',
#  'https://medlineplus.gov/lab-tests/alpha-1-antitrypsin-test/',
#  'https://medlineplus.gov/lab-tests/alpha-fetoprotein-afp-test/',
#  'https://medlineplus.gov/lab-tests/alt-blood-test/',
#  'https://medlineplus.gov/lab-tests/ammonia-levels/',
#  'https://medlineplus.gov/lab-tests/amniocentesis-amniotic-fluid-test/',
#  'https://medlineplus.gov/lab-tests/amylase-test/',
#  'https://medlineplus.gov/lab-tests/ana-antinuclear-antibody-test/',
#  'https://medlineplus.gov/lab-tests/anion-gap-blood-test/',
#  'https://medlineplus.gov/lab-tests/anoscopy/',
#  'https://medlineplus.gov/lab-tests/anti-mullerian-hormone-test/',
#  'https://medlineplus.gov/lab-tests/antibiotic-sensitivity-test/',
#  'https://medlineplus.gov/lab-tests/antibody-serology-tests/',
#  'https://medlineplus.gov/lab-tests/antineutrophil-cytoplasmic-antibodies-anca-test/',
#  'https://medlineplus.gov/lab-tests/appendicitis-tests/',
#  'https://medlineplus.gov/lab-tests/arterial-blood-gas-abg-test/',
#  'https://medlineplus.gov/lab-tests/ast-test/',
#  'https://medlineplus.gov/lab-tests/at-home-medical-tests/',
#  'https://medlineplus.gov/lab-tests/autism-spectrum-disorder-asd-screening/',
#  'https://medlineplus.gov/lab-tests/autonomic-testing/',
#  'https://medlineplus.gov/lab-tests/bacteria-culture-test/',
#  'https://medlineplus.gov/lab-tests/bacterial-vaginosis-test/',
#  'https://medlineplus.gov/lab-tests/balance-tests/',
#  'https://medlineplus.gov/lab-tests/barium-swallow/',
#  'https://medlineplus.gov/lab-tests/basic-metabolic-panel-bmp/',
#  'https://medlineplus.gov/lab-tests/bcr-abl-genetic-test/',
#  'https://medlineplus.gov/lab-tests/beta-2-microglobulin-b2m-tumor-marker-test/',
#  'https://medlineplus.gov/lab-tests/bilirubin-blood-test/',
#  'https://medlineplus.gov/lab-tests/bilirubin-in-urine/',
#  'https://medlineplus.gov/lab-tests/blood-alcohol-level/',
#  'https://medlineplus.gov/lab-tests/blood-differential/',
#  'https://medlineplus.gov/lab-tests/blood-glucose-test/',
#  'https://medlineplus.gov/lab-tests/blood-in-urine/',
#  'https://medlineplus.gov/lab-tests/blood-smear/',
#  'https://medlineplus.gov/lab-tests/bone-density-scan/',
#  'https://medlineplus.gov/lab-tests/bone-marrow-tests/',
#  'https://medlineplus.gov/lab-tests/braf-genetic-test/',
#  'https://medlineplus.gov/lab-tests/brca-test/',
#  'https://medlineplus.gov/lab-tests/breast-biopsy/',
#  'https://medlineplus.gov/lab-tests/bronchoscopy-and-bronchoalveolar-lavage-bal/',
#  'https://medlineplus.gov/lab-tests/bun-blood-urea-nitrogen/',
#  'https://medlineplus.gov/lab-tests/burn-evaluation/',
#  'https://medlineplus.gov/lab-tests/c-peptide-test/',
#  'https://medlineplus.gov/lab-tests/c-reactive-protein-crp-test/',
#  'https://medlineplus.gov/lab-tests/c-diff-testing/',
#  'https://medlineplus.gov/lab-tests/ca-19-9-blood-test-pancreatic-cancer/',
#  'https://medlineplus.gov/lab-tests/ca-125-blood-test-ovarian-cancer/',
#  'https://medlineplus.gov/lab-tests/calcitonin-test/',
#  'https://medlineplus.gov/lab-tests/calcium-blood-test/',
#  'https://medlineplus.gov/lab-tests/calcium-in-urine-test/',
#  'https://medlineplus.gov/lab-tests/carbon-dioxide-co2-in-blood/',
#  'https://medlineplus.gov/lab-tests/catecholamine-tests/',
#  'https://medlineplus.gov/lab-tests/ccp-antibody-test/',
#  'https://medlineplus.gov/lab-tests/cd4-lymphocyte-count/',
#  'https://medlineplus.gov/lab-tests/cea-test/',
#  'https://medlineplus.gov/lab-tests/celiac-disease-screening/',
#  'https://medlineplus.gov/lab-tests/cerebrospinal-fluid-csf-analysis/',
#  'https://medlineplus.gov/lab-tests/ceruloplasmin-test/',
#  'https://medlineplus.gov/lab-tests/chickenpox-and-shingles-tests/',
#  'https://medlineplus.gov/lab-tests/chlamydia-test/',
#  'https://medlineplus.gov/lab-tests/chloride-blood-test/',
#  'https://medlineplus.gov/lab-tests/cholesterol-levels/',
#  'https://medlineplus.gov/lab-tests/chorionic-villus-sampling-cvs/',
#  'https://medlineplus.gov/lab-tests/chymotrypsin-in-stool/',
#  'https://medlineplus.gov/lab-tests/coagulation-factor-tests/',
#  'https://medlineplus.gov/lab-tests/cognitive-testing/',
#  'https://medlineplus.gov/lab-tests/cold-stimulation-test/',
#  'https://medlineplus.gov/lab-tests/colorectal-cancer-screening-tests/',
#  'https://medlineplus.gov/lab-tests/colposcopy/',
#  'https://medlineplus.gov/lab-tests/complement-blood-test/',
#  'https://medlineplus.gov/lab-tests/complete-blood-count-cbc/',
#  'https://medlineplus.gov/lab-tests/comprehensive-metabolic-panel-cmp/',
#  'https://medlineplus.gov/lab-tests/concussion-tests/',
#  'https://medlineplus.gov/lab-tests/cord-blood-testing-and-banking/',
#  'https://medlineplus.gov/lab-tests/cortisol-test/',
#  'https://medlineplus.gov/lab-tests/creatine-kinase/',
#  'https://medlineplus.gov/lab-tests/creatinine-test/',
#  'https://medlineplus.gov/lab-tests/crystals-in-urine/',
#  'https://medlineplus.gov/lab-tests/csf-immunoglobulin-g-igg-index/',
#  'https://medlineplus.gov/lab-tests/cytomegalovirus-cmv-tests/',
#  'https://medlineplus.gov/lab-tests/d-dimer-test/',
#  'https://medlineplus.gov/lab-tests/dengue-fever-test/',
#  'https://medlineplus.gov/lab-tests/dental-exam/',
#  'https://medlineplus.gov/lab-tests/depression-screening/',
#  'https://medlineplus.gov/lab-tests/developmental-and-behavioral-screening-tests/',
#  'https://medlineplus.gov/lab-tests/dhea-sulfate-test/',
#  'https://medlineplus.gov/lab-tests/diabetes-tests/',
#  'https://medlineplus.gov/lab-tests/diabetic-foot-exam/',
#  'https://medlineplus.gov/lab-tests/differential-diagnosis/',
#  'https://medlineplus.gov/lab-tests/doppler-ultrasound/',
#  'https://medlineplus.gov/lab-tests/down-syndrome-tests/',
#  'https://medlineplus.gov/lab-tests/drug-testing/',
#  'https://medlineplus.gov/lab-tests/drug-use-screening-tests/',
#  'https://medlineplus.gov/lab-tests/dysphagia-tests/',
#  'https://medlineplus.gov/lab-tests/elastography/',
#  'https://medlineplus.gov/lab-tests/electrocardiogram/',
#  'https://medlineplus.gov/lab-tests/electrolyte-panel/',
#  'https://medlineplus.gov/lab-tests/electromyography-emg-and-nerve-conduction-studies/',
#  'https://medlineplus.gov/lab-tests/epithelial-cells-in-urine/',
#  'https://medlineplus.gov/lab-tests/erythrocyte-sedimentation-rate-esr/',
#  'https://medlineplus.gov/lab-tests/esophageal-ph-test/',
#  'https://medlineplus.gov/lab-tests/estrogen-levels-test/',
#  'https://medlineplus.gov/lab-tests/estrogen-receptor-progesterone-receptor-tests/',
#  'https://medlineplus.gov/lab-tests/fall-risk-assessment/',
#  'https://medlineplus.gov/lab-tests/fasting-for-a-blood-test/',
#  'https://medlineplus.gov/lab-tests/fecal-occult-blood-test-fobt/',
#  'https://medlineplus.gov/lab-tests/ferritin-blood-test/',
#  'https://medlineplus.gov/lab-tests/fetal-alcohol-spectrum-disorders-fasd-screening/',
#  'https://medlineplus.gov/lab-tests/flu-influenza-test/',
#  'https://medlineplus.gov/lab-tests/fluoroscopy/',
#  'https://medlineplus.gov/lab-tests/follicle-stimulating-hormone-fsh-levels-test/',
#  'https://medlineplus.gov/lab-tests/food-allergy-testing/',
#  'https://medlineplus.gov/lab-tests/free-light-chains/',
#  'https://medlineplus.gov/lab-tests/fungal-culture-test/',
#  'https://medlineplus.gov/lab-tests/g6pd-test/',
#  'https://medlineplus.gov/lab-tests/galactosemia-tests/',
#  'https://medlineplus.gov/lab-tests/gamma-glutamyl-transferase-ggt-test/',
#  'https://medlineplus.gov/lab-tests/gastric-emptying-tests/',
#  'https://medlineplus.gov/lab-tests/glaucoma-tests/',
#  'https://medlineplus.gov/lab-tests/globulin-test/',
#  'https://medlineplus.gov/lab-tests/glomerular-filtration-rate-gfr-test/',
#  'https://medlineplus.gov/lab-tests/glucagon-blood-test/',
#  'https://medlineplus.gov/lab-tests/glucose-in-urine-test/',
#  'https://medlineplus.gov/lab-tests/gonorrhea-test/',
#  'https://medlineplus.gov/lab-tests/gram-stain/',
#  'https://medlineplus.gov/lab-tests/growth-hormone-tests/',
#  'https://medlineplus.gov/lab-tests/haptoglobin-hp-test/',
#  'https://medlineplus.gov/lab-tests/hearing-tests-for-adults/',
#  'https://medlineplus.gov/lab-tests/hearing-tests-for-children/',
#  'https://medlineplus.gov/lab-tests/heart-disease-risk-assessment/',
#  'https://medlineplus.gov/lab-tests/heavy-metal-blood-test/',
#  'https://medlineplus.gov/lab-tests/helicobacter-pylori-h-pylori-tests/',
#  'https://medlineplus.gov/lab-tests/hematocrit-test/',
#  'https://medlineplus.gov/lab-tests/hemoglobin-a1c-hba1c-test/',
#  'https://medlineplus.gov/lab-tests/hemoglobin-electrophoresis/',
#  'https://medlineplus.gov/lab-tests/hemoglobin-test/',
#  'https://medlineplus.gov/lab-tests/hepatitis-panel/',
#  'https://medlineplus.gov/lab-tests/her2-breast-cancer-testing/',
#  'https://medlineplus.gov/lab-tests/herpes-hsv-test/',
#  'https://medlineplus.gov/lab-tests/hiv-screening-test/',
#  'https://medlineplus.gov/lab-tests/hiv-viral-load/',
#  'https://medlineplus.gov/lab-tests/homocysteine-test/',
#  'https://medlineplus.gov/lab-tests/how-to-cope-with-medical-test-anxiety/',
#  'https://medlineplus.gov/lab-tests/how-to-prepare-for-a-lab-test/',
#  'https://medlineplus.gov/lab-tests/how-to-prepare-your-child-for-a-lab-test/',
#  'https://medlineplus.gov/lab-tests/how-to-understand-your-lab-results/',
#  'https://medlineplus.gov/lab-tests/human-papillomavirus-hpv-test/',
#  'https://medlineplus.gov/lab-tests/hysteroscopy/',
#  'https://medlineplus.gov/lab-tests/igf-1-insulin-like-growth-factor-1-test/',
#  'https://medlineplus.gov/lab-tests/immunofixation-ife-blood-test/',
#  'https://medlineplus.gov/lab-tests/immunoglobulins-blood-test/',
#  'https://medlineplus.gov/lab-tests/insulin-in-blood/',
#  'https://medlineplus.gov/lab-tests/intravenous-pyelogram-ivp/',
#  'https://medlineplus.gov/lab-tests/iron-tests/',
#  'https://medlineplus.gov/lab-tests/karyotype-genetic-test/',
#  'https://medlineplus.gov/lab-tests/ketones-in-blood/',
#  'https://medlineplus.gov/lab-tests/ketones-in-urine/',
#  'https://medlineplus.gov/lab-tests/kidney-stone-analysis/',
#  'https://medlineplus.gov/lab-tests/lactate-dehydrogenase-ldh-isoenzymes-test/',
#  'https://medlineplus.gov/lab-tests/lactate-dehydrogenase-ldh-test/',
#  'https://medlineplus.gov/lab-tests/lactic-acid-test/',
#  'https://medlineplus.gov/lab-tests/lactose-tolerance-tests/',
#  'https://medlineplus.gov/lab-tests/laparoscopy/',
#  'https://medlineplus.gov/lab-tests/legionella-tests/',
#  'https://medlineplus.gov/lab-tests/lipase-tests/',
#  'https://medlineplus.gov/lab-tests/lipoprotein-a-blood-test/',
#  'https://medlineplus.gov/lab-tests/liver-function-tests/',
#  'https://medlineplus.gov/lab-tests/lung-cancer-tumor-markers/',
#  'https://medlineplus.gov/lab-tests/lung-function-tests/',
#  'https://medlineplus.gov/lab-tests/luteinizing-hormone-lh-levels-test/',
#  'https://medlineplus.gov/lab-tests/lyme-disease-tests/',
#  'https://medlineplus.gov/lab-tests/magnesium-blood-test/',
#  'https://medlineplus.gov/lab-tests/malaria-tests/',
#  'https://medlineplus.gov/lab-tests/mcv-mean-corpuscular-volume/',
#  'https://medlineplus.gov/lab-tests/measles-and-mumps-tests/',
#  'https://medlineplus.gov/lab-tests/measuring-blood-pressure/',
#  'https://medlineplus.gov/lab-tests/mental-health-screening/',
#  'https://medlineplus.gov/lab-tests/methylmalonic-acid-mma-test/',
#  'https://medlineplus.gov/lab-tests/microalbumin-creatinine-ratio/',
#  'https://medlineplus.gov/lab-tests/mononucleosis-mono-tests/',
#  'https://medlineplus.gov/lab-tests/mpv-blood-test/',
#  'https://medlineplus.gov/lab-tests/mrsa-tests/',
#  'https://medlineplus.gov/lab-tests/mthfr-mutation-test/',
#  'https://medlineplus.gov/lab-tests/mucus-in-urine/',
#  'https://medlineplus.gov/lab-tests/myasthenia-gravis-tests/',
#  'https://medlineplus.gov/lab-tests/myelography/',
#  'https://medlineplus.gov/lab-tests/nasal-swab/',
#  'https://medlineplus.gov/lab-tests/natriuretic-peptide-tests-bnp-nt-probnp/',
#  'https://medlineplus.gov/lab-tests/neurological-exam/',
#  'https://medlineplus.gov/lab-tests/nitrites-in-urine/',
#  'https://medlineplus.gov/lab-tests/nonstress-test/',
#  'https://medlineplus.gov/lab-tests/obesity-screening/',
#  'https://medlineplus.gov/lab-tests/obsessive-compulsive-disorder-ocd-test/',
#  'https://medlineplus.gov/lab-tests/opioid-testing/',
#  'https://medlineplus.gov/lab-tests/osmolality-tests/',
#  'https://medlineplus.gov/lab-tests/ova-and-parasite-test/',
#  'https://medlineplus.gov/lab-tests/panic-disorder-test/',
#  'https://medlineplus.gov/lab-tests/pap-smear/',
#  'https://medlineplus.gov/lab-tests/parainfluenza-tests/',
#  'https://medlineplus.gov/lab-tests/parathyroid-hormone-pth-test/',
#  'https://medlineplus.gov/lab-tests/partial-thromboplastin-time-ptt-test/',
#  'https://medlineplus.gov/lab-tests/pcr-tests/',
#  'https://medlineplus.gov/lab-tests/pdl1-immunotherapy-tests/',
#  'https://medlineplus.gov/lab-tests/pet-scan/',
#  'https://medlineplus.gov/lab-tests/pharmacogenetic-tests/',
#  'https://medlineplus.gov/lab-tests/phenylketonuria-pku-screening/',
#  'https://medlineplus.gov/lab-tests/phosphate-in-blood/',
#  'https://medlineplus.gov/lab-tests/phosphate-in-urine/',
#  'https://medlineplus.gov/lab-tests/platelet-tests/',
#  'https://medlineplus.gov/lab-tests/pleural-fluid-analysis/',
#  'https://medlineplus.gov/lab-tests/porphyrin-tests/',
#  'https://medlineplus.gov/lab-tests/postpartum-depression-screening/',
#  'https://medlineplus.gov/lab-tests/potassium-blood-test/',
#  'https://medlineplus.gov/lab-tests/prealbumin-blood-test/',
#  'https://medlineplus.gov/lab-tests/pregnancy-test/',
#  'https://medlineplus.gov/lab-tests/prenatal-cell-free-dna-screening/',
#  'https://medlineplus.gov/lab-tests/prenatal-panel/',
#  'https://medlineplus.gov/lab-tests/procalcitonin-test/',
#  'https://medlineplus.gov/lab-tests/progesterone-test/',
#  'https://medlineplus.gov/lab-tests/prolactin-levels/',
#  'https://medlineplus.gov/lab-tests/prostate-specific-antigen-psa-test/',
#  'https://medlineplus.gov/lab-tests/protein-c-and-protein-s-tests/',
#  'https://medlineplus.gov/lab-tests/protein-in-urine/',
#  'https://medlineplus.gov/lab-tests/prothrombin-time-test-and-inr-ptinr/',
#  'https://medlineplus.gov/lab-tests/pten-genetic-test/',
#  'https://medlineplus.gov/lab-tests/pulse-oximetry/',
#  'https://medlineplus.gov/lab-tests/rapid-tests/',
#  'https://medlineplus.gov/lab-tests/rash-evaluation/',
#  'https://medlineplus.gov/lab-tests/rdw-red-cell-distribution-width/',
#  'https://medlineplus.gov/lab-tests/red-blood-cell-rbc-count/',
#  'https://medlineplus.gov/lab-tests/red-blood-cell-rbc-indices/',
#  'https://medlineplus.gov/lab-tests/red-blood-cell-antibody-screen/',
#  'https://medlineplus.gov/lab-tests/renin-test/',
#  'https://medlineplus.gov/lab-tests/respiratory-pathogens-panel/',
#  'https://medlineplus.gov/lab-tests/respiratory-syncytial-virus-rsv-tests/',
#  'https://medlineplus.gov/lab-tests/reticulocyte-count/',
#  'https://medlineplus.gov/lab-tests/rheumatoid-factor-rf-test/',
#  'https://medlineplus.gov/lab-tests/salicylates-level/',
#  'https://medlineplus.gov/lab-tests/semen-analysis/',
#  'https://medlineplus.gov/lab-tests/sentinel-lymph-node-biopsy/',
#  'https://medlineplus.gov/lab-tests/shbg-blood-test/',
#  'https://medlineplus.gov/lab-tests/skin-biopsy/',
#  'https://medlineplus.gov/lab-tests/skin-cancer-screening/',
#  'https://medlineplus.gov/lab-tests/sleep-study/',
#  'https://medlineplus.gov/lab-tests/smooth-muscle-antibody-sma-test/',
#  'https://medlineplus.gov/lab-tests/sodium-blood-test/',
#  'https://medlineplus.gov/lab-tests/sputum-culture/',
#  'https://medlineplus.gov/lab-tests/std-tests/',
#  'https://medlineplus.gov/lab-tests/stool-elastase/',
#  'https://medlineplus.gov/lab-tests/strep-a-test/',
#  'https://medlineplus.gov/lab-tests/strep-b-test/',
#  'https://medlineplus.gov/lab-tests/stress-tests/',
#  'https://medlineplus.gov/lab-tests/suicide-risk-screening/',
#  'https://medlineplus.gov/lab-tests/sweat-test-for-cystic-fibrosis/',
#  'https://medlineplus.gov/lab-tests/synovial-fluid-analysis/',
#  'https://medlineplus.gov/lab-tests/syphilis-tests/',
#  'https://medlineplus.gov/lab-tests/testosterone-levels-test/',
#  'https://medlineplus.gov/lab-tests/therapeutic-drug-monitoring/',
#  'https://medlineplus.gov/lab-tests/thyroglobulin/',
#  'https://medlineplus.gov/lab-tests/thyroid-antibodies/',
#  'https://medlineplus.gov/lab-tests/thyroxine-t4-test/',
#  'https://medlineplus.gov/lab-tests/total-protein-and-albumin-globulin-a-g-ratio/',
#  'https://medlineplus.gov/lab-tests/tp53-genetic-test/',
#  'https://medlineplus.gov/lab-tests/trichomoniasis-test/',
#  'https://medlineplus.gov/lab-tests/tricyclic-antidepressant-tca-screen/',
#  'https://medlineplus.gov/lab-tests/triglycerides-test/',
#  'https://medlineplus.gov/lab-tests/triiodothyronine-t3-tests/',
#  'https://medlineplus.gov/lab-tests/troponin-test/',
#  'https://medlineplus.gov/lab-tests/tsh-thyroid-stimulating-hormone-test/',
#  'https://medlineplus.gov/lab-tests/tuberculosis-screening/',
#  'https://medlineplus.gov/lab-tests/tumor-marker-tests/',
#  'https://medlineplus.gov/lab-tests/sonogram/',
#  'https://medlineplus.gov/lab-tests/uric-acid-test/',
#  'https://medlineplus.gov/lab-tests/urobilinogen-in-urine/',
#  'https://medlineplus.gov/lab-tests/vq-scan/',
#  'https://medlineplus.gov/lab-tests/videonystagmography-vng/',
#  'https://medlineplus.gov/lab-tests/vision-screening/',
#  'https://medlineplus.gov/lab-tests/vitamin-b-test/',
#  'https://medlineplus.gov/lab-tests/vitamin-d-test/',
#  'https://medlineplus.gov/lab-tests/vitamin-e-tocopherol-test/',
#  'https://medlineplus.gov/lab-tests/what-you-need-to-know-about-blood-testing/',
#  'https://medlineplus.gov/lab-tests/white-blood-cell-wbc-in-stool/',
#  'https://medlineplus.gov/lab-tests/white-blood-count-wbc/',
#  'https://medlineplus.gov/lab-tests/whooping-cough-diagnosis/',
#  'https://medlineplus.gov/lab-tests/xylose-testing/',
#  'https://medlineplus.gov/lab-tests/yeast-infection-tests/',
#  'https://medlineplus.gov/lab-tests/zika-virus-test/']

# %%
u=links["section_A"][0]
res2 = requests.get(u)
get = bs(res2.content,'html.parser')
# get.find_all('div',class_ = 'mp-content')
get

# %%
def extract_text(url):
    res = requests.get(url)
    content = bs(res.content,'html.parser')
    all_text = content.find_all('div',class_='mp-content')

    heading = content.find_all('div',class_='page-title')[0].find_all('h1')[0].text
    text = ''
    for x in all_text:
        x = x.find_all(['h1','h2','li','p'])
        text = text + '1'+" ".join([i.text for i in x])
    return heading+" : "+text


extract_text(links[0])
# Out:
# "Acetaminophen Level : 1What is an acetaminophen level test? This test measures the amount of acetaminophen in the blood. Acetaminophen is one of the most common medicines used in over-the-counter pain relievers and fever reducers. It is found in more than 200 brand name medicines. These include Tylenol, Excedrin, Nyquil, and Paracetamol, which is commonly found outside the U. S. Acetaminophen is safe and effective when taken at the proper dose. But an overdose can cause serious and sometimes deadly liver damage. Unfortunately, dosing mistakes are common. Reasons for this include: Taking more than one medicine that contains acetaminophen. Many cold, flu, and allergy medicines contain acetaminophen. If you take more than one medicine with acetaminophen, you may end up taking an unsafe dose without realizing it Not following dose recommendations. The adult maximum dose is generally 4000 mgs in 24 hours. But that may be too much for some people. So it may be safer to limit your dose to 3000 mgs per day. Children's dosing recommendations depend on their weight and age. Giving a child an adult version of the medicine, rather than a version designed for children If you think you or your child has taken too much acetaminophen, call your health care provider right away. You may need to be tested and treated in the emergency room. Other names: acetaminophen drug test, acetaminophen blood test, Paracetamol test, Tylenol drug test1What is it used for? The test is used to find out if you or your child has taken too much acetaminophen.1Why do I need an acetaminophen level test? Your provider may order a test if you or your child has symptoms of an overdose. Symptoms may happen as soon as two to three hours after taking the medicine but can take as long as 12 hours to appear. Symptoms in adults and children are similar and may include: Nausea and vomiting Diarrhea Abdominal pain Loss of appetite Fatigue Irritability Sweating Jaundice, a condition that causes your skin and eyes to turn yellow1What happens during an acetaminophen level test? A health care professional will take a blood sample from a vein in your arm, using a small needle. After the needle is inserted, a small amount of blood will be collected into a test tube or vial. You may feel a little sting when the needle goes in or out. This usually takes less than five minutes.1Will I need to do anything to prepare for the test? You don't need any special preparations for an acetaminophen level test.1Are there any risks to an acetaminophen level test? There is very little risk to having a blood test. You may have slight pain or bruising at the spot where the needle was put in, but most symptoms go away quickly.1What do the results mean? If results show a high level of acetaminophen, you or your child may be at risk for liver damage and may need immediate treatment. The type of treatment will depend on how much excess acetaminophen is in your system. After you get your results, your provider may repeat this test every four to six hours to make sure you are out of danger. If you have questions about your results, talk to your health care provider. Learn more about laboratory tests, reference ranges, and understanding results.1Is there anything else I need to know about an acetaminophen level test? Before you or your child take any medicine, read the label carefully. Make sure that you only use the recommended dose. Check the ingredient list to see whether the medicines contain acetaminophen, so that you don't take too much. Common medicines that contain acetaminophen include: Nyquil Dayquil Dristan Contact Theraflu Actifed Mucinex Sudafed Also, if you drink three or more alcoholic beverages a day, ask your health care provider if it is safe to take acetaminophen. Drinking alcohol while taking acetaminophen can increase your risk of liver damage.1References CHOC Children's [Internet]. Orange (CA): CHOC Children's; c2020. The Dangers of Acetaminophen for Children; [cited 2020 Mar 18]; [ab ...

# %%
final_text = []

for link in links:
    final_text.append(extract_text(link))

# %%
with open("data.txt", "w",encoding="utf-8") as output:
    output.write(" ".join(final_text))
